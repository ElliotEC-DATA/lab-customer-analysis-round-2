# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('/Users/accountmanager/Desktop/Iron Hack/Unit_1/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv')
df1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df1.shape
# Out:
# (10910, 26)

# %%
df1.columns = df1.columns.str.lower()
df1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
df1.dtypes
# Out:
# unnamed: 0                         int64
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# ...

# %%
numeric_data = df1.select_dtypes(include=[np.number])
categorical_data = df1.select_dtypes(exclude=[np.number])

print(numeric_data.shape[1])
print(categorical_data.shape[1])
# Out:
# 9
# 17

# %%
df = df1.fillna('')
df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877                          6857.519928
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df_time = df['Effective To Date']
df_time
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 df_time = strftime.df['Effective To Date']
#       2 df_time
#
# NameError: name 'strftime' is not defined

# %%
np.percentile(df_time, [25]) # how do I convert the values in numbers ?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 np.percentile(df_time, [25])
#
# File <__array_function__ internals>:5, in percentile(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py:3867, in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3865 if not _quantile_is_valid(q):
#    3866     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 3867 return _quantile_unchecked(
#    3868     a, q, axis, out, overwrite_input, interpolation, keepdims)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py:3986, in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3983 def _quantile_unchecked(a, q, axis=None, out=None, overwrite_input=False,
# ...

# %%
# lab 3 starting here

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df.columns = df.columns.str.lower()
df
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877                          6857.519928
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
df.shape
# Out:
# (10910, 26)

# %%
df.describe()
# Out:
#          Unnamed: 0  Customer Lifetime Value        Income  \
# count  10910.000000             10910.000000  10910.000000
# mean    5454.500000              8018.241094  37536.284785
# std     3149.590053              6885.081434  30359.195670
# min        0.000000              1898.007675      0.000000
# 25%     2727.250000              4014.453113      0.000000
# 50%     5454.500000              5771.147235  33813.500000
# 75%     8181.750000              8992.779137  62250.750000
# max    10909.000000             83325.381190  99981.000000
#
#        Monthly Premium Auto  Months Since Policy Inception  \
# count          10910.000000                   10910.000000
# mean              93.196059                      48.091934
# std               34.442532                      27.940675
# min               61.000000                       0.000000
# 25%               68.000000                      24.000000
# 50%               83.000000                      48.000000
# ...

# %%
df[df.columns].value_counts().hist()
plt.show()

# %%
df
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877                          6857.519928
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
df
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877                          6857.519928
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
nb_yes = df[df['response'] == 'Yes']['sales channel'].count()
nb_no = df[df['response'] == 'No']['sales channel'].count()
print(nb_yes)
print(nb_no)

plt.figure(figsize=(16,8))

sns.barplot(data = df ,x = "sales channel", y = nb_yes)
plt.show()

# I've tried but I don't know why python interpret 'nb_yes' as a boolean
# Out:
# 1466
# 8813
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [110], in <cell line: 8>()
#       4 print(nb_no)
#       6 plt.figure(figsize=(16,8))
# ----> 8 sns.barplot(data = df ,x = "sales channel", y = 'nb_yes')
#       9 plt.show()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
plt.figure(figsize=(16,8))

sns.barplot(data = df ,x = "response", y = 'total claim amount',hue = 'response')
plt.show()

# %%
plt.figure(figsize=(16,8))

sns.barplot(data = df , y = 'income',x = "response", hue = 'response')
plt.show()

# %%
plt.scatter(df['response'], df['income'])
plt.show()
